# %% [markdown]
# # Text Generation with Neural Networks

# %% [markdown]
# ## Functions for Processing Text
#
# ### Reading in files as a string text

# %%
def read_file(filepath):
    
    with open(filepath) as f:
        str_text = f.read()
    
    return str_text

# %%
doc =read_file('game_of_thrones.txt')

# %%
len(doc)
# Out:
# 40198

# %% [markdown]
# ### Tokenize and Clean Text

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'tagger', 'ner'])

# %%
nlp.max_length = 40199

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
d = read_file('game_of_thrones.txt')
tokens = separate_punc(d)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
tokens
# Out:
# ['a',
#  'song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'a',
#  'game',
#  'of',
#  'thrones',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them',
#  'the',
#  'wildlings',
#  'are',
#  'dead',
#  'do',
#  'the',
#  'dead',
#  'frighten',
#  'you',
#  'ser',
#  'waymar',
#  'royce',
#  'asked',
#  'with',
#  'just',
#  'the',
#  'hint',
#  'of',
#  'a',
#  'smile',
#  'gared',
#  'did',
#  'not',
#  'rise',
#  'to',
#  'the',
#  'bait',
#  'he',
#  'was',
#  'an',
#  'old',
#  'man',
#  'past',
#  'fifty',
#  'and',
#  'he',
#  'had',
#  'seen',
#  'the',
#  'lordlings',
#  'come',
#  'and',
#  'go',
#  'dead',
#  'is',
#  'dead',
#  'he',
#  'said',
#  'we',
#  'have',
#  'no',
#  'business',
#  'with',
#  'the',
#  'dead',
#  'are',
#  'they',
#  'dead',
#  'royce',
#  'asked',
#  'softly',
#  'what',
#  'proof',
#  'have',
#  'we',
#  'will',
#  'saw',
#  'them',
#  'gared',
#  'said',
#  'if',
#  'he',
#  'says',
#  'they',
#  'are',
#  'dead',
#  'that',
#  "'s",
#  'proof',
#  'enough',
#  'for',
#  'me',
#  'will',
#  'had',
#  'known',
#  'they',
#  'would',
#  'drag',
#  'him',
#  'into',
#  'the',
#  'quarrel',
#  'sooner',
#  'or',
#  'later',
#  'he',
#  'wished',
#  'it',
#  'had',
#  'been',
#  'later',
#  'rather',
#  'than',
#  'sooner',
#  'my',
#  'mother',
#  'told',
#  'me',
#  'that',
#  'dead',
#  'men',
#  'sing',
#  'no',
#  'songs',
#  'he',
#  'put',
#  'in',
#  'my',
#  'wet',
#  'nurse',
#  'said',
#  'the',
#  'same',
#  'thing',
#  'will',
#  'royce',
#  'replied',
#  'never',
#  'believe',
#  'anything',
#  'you',
#  'hear',
#  'at',
#  'a',
#  'woman',
#  "'s",
#  'tit',
#  'there',
#  'are',
#  'things',
#  'to',
#  'be',
#  'learned',
#  'even',
#  'from',
#  'the',
#  'dead',
#  'his',
#  'voice',
#  'echoed',
#  'too',
#  'loud',
#  'in',
#  'the',
#  'twilit',
#  'forest',
#  'we',
#  'have',
#  'a',
#  'long',
#  'ride',
#  'before',
#  'us',
#  'gared',
#  'pointed',
#  'out',
#  'eight',
#  'days',
#  'maybe',
#  'nine',
#  'and',
#  'night',
#  'is',
#  'falling',
#  'ser',
#  'waymar',
#  'royce',
#  'glanced',
#  'at',
#  'the',
#  'sky',
#  'with',
#  'disinterest',
#  'it',
#  'does',
#  'that',
#  'every',
#  'day',
#  'about',
#  'this',
#  'time',
#  'are',
#  'you',
#  'unmanned',
#  'by',
#  'the',
#  'dark',
#  'gared',
#  'will',
#  'could',
#  'see',
#  'the',
#  'tightness',
#  'around',
#  'gared',
#  "'s",
#  'mouth',
#  'the',
#  'barely',
#  'suppressed',
#  'anger',
#  'in',
#  'his',
#  'eyes',
#  'under',
#  'the',
#  'thick',
#  'black',
#  'hood',
#  'of',
#  'his',
#  'cloak',
#  'gared',
#  'had',
#  'spent',
#  'forty',
#  'years',
#  'in',
#  'the',
#  'night',
#  "'s",
#  'watch',
#  'man',
#  'and',
#  'boy',
#  'and',
#  'he',
#  'was',
#  'not',
#  'accustomed',
#  'to',
#  'being',
#  'made',
#  'light',
#  'of',
#  'yet',
#  'it',
#  'was',
#  'more',
#  'than',
#  'that',
#  'under',
#  'the',
#  'wounded',
#  'pride',
#  'will',
#  'could',
#  'sense',
#  'something',
#  'else',
#  'in',
#  'the',
#  'older',
#  'man',
#  'you',
#  'could',
#  'taste',
#  'it',
#  'a',
#  'nervous',
#  'tension',
#  'that',
#  'came',
#  'perilous',
#  'close',
#  'to',
#  'fear',
#  'will',
#  'shared',
#  'his',
#  'unease',
#  'he',
#  'had',
#  'been',
#  'four',
#  'years',
#  'on',
#  'the',
#  'wall',
#  'the',
#  'first',
#  'time',
#  'he',
#  'had',
#  'been',
#  'sent',
#  'beyond',
#  'all',
#  'the',
#  'old',
#  'stories',
#  'had',
#  'come',
#  'rushing',
#  'back',
#  'and',
#  'his',
#  'bowels',
#  'had',
#  'turned',
#  'to',
#  'water',
#  'he',
#  'had',
#  'laughed',
#  'about',
#  'it',
#  'afterward',
#  'he',
#  'was',
#  'a',
#  'veteran',
#  'of',
#  'a',
#  'hundred',
#  'rangings',
#  'by',
#  'now',
#  'and',
#  'the',
#  'endless',
#  'dark',
#  'wilderness',
#  'that',
#  'the',
#  'southron',
#  'called',
#  'the',
#  'haunted',
#  'forest',
#  'had',
#  'no',
#  'more',
#  'terrors',
#  'for',
#  'him',
#  'until',
#  'tonight',
#  'something',
#  'was',
#  'different',
#  'tonight',
#  'there',
#  'was',
#  'an',
#  'edge',
#  'to',
#  'this',
#  'darkness',
#  'that',
#  'made',
#  'his',
#  'hackles',
#  'rise',
#  'nine',
#  'days',
#  'they',
#  'had',
#  'been',
#  'riding',
#  'north',
#  'and',
#  'northwest',
#  'and',
#  'then',
#  'north',
#  'again',
#  'farther',
#  'and',
#  'farther',
#  'from',
#  'the',
#  'wall',
#  'hard',
#  'on',
#  'the',
#  'track',
#  'of',
#  'a',
#  'band',
#  'of',
#  'wildling',
#  'raiders',
#  'each',
#  'day',
#  'had',
#  'been',
#  'worse',
#  'than',
#  'the',
#  'day',
#  'that',
#  'had',
#  'come',
#  'before',
#  'it',
#  'today',
#  'was',
#  'the',
#  'worst',
#  'of',
#  'all',
#  'a',
#  'cold',
#  'wind',
#  'was',
#  'blowing',
#  'out',
#  'of',
#  'the',
#  'north',
#  'and',
#  'it',
#  'made',
#  'the',
#  'trees',
#  'rustle',
#  'like',
#  'living',
#  'things',
#  'all',
#  'day',
#  'will',
#  'had',
#  'felt',
#  'as',
#  'though',
#  'something',
#  'were',
#  'watching',
#  'him',
#  'something',
#  'cold',
#  'and',
#  'implacable',
#  'that',
#  'loved',
#  'him',
#  'not',
#  'gared',
#  'had',
#  'felt',
#  'it',
#  'too',
#  'will',
#  'wanted',
#  'nothing',
#  'so',
#  'much',
#  'as',
#  'to',
#  'ride',
#  'hellbent',
#  'for',
#  'the',
#  'safety',
#  'of',
#  'the',
#  'wall',
#  'but',
#  'that',
#  'was',
#  'not',
#  'a',
#  'feeling',
#  'to',
#  'share',
#  'with',
#  'your',
#  'commander',
#  'especially',
#  'not',
#  'a',
#  'commander',
#  'like',
#  'this',
#  'one',
#  'ser',
#  'waymar',
#  'royce',
#  'was',
#  'the',
#  'youngest',
#  'son',
#  'of',
#  'an',
#  'ancient',
#  'house',
#  'with',
#  'too',
#  'many',
#  'heirs',
#  'he',
#  'was',
#  'a',
#  'handsome',
#  'youth',
#  'of',
#  'eighteen',
#  'grey',
#  'eyed',
#  'and',
#  'graceful',
#  'and',
#  'slender',
#  'as',
#  'a',
#  'knife',
#  'mounted',
#  'on',
#  'his',
#  'huge',
#  'black',
#  'destrier',
#  'the',
#  'knight',
#  'towered',
#  'above',
#  'will',
#  'and',
#  'gared',
#  'on',
#  'their',
#  'smaller',
#  'garrons',
#  'he',
#  'wore',
#  'black',
#  'leather',
#  'boots',
#  'black',
#  'woolen',
#  'pants',
#  'black',
#  'moleskin',
#  'gloves',
#  'and',
#  'a',
#  'fine',
#  'supple',
#  'coat',
#  'of',
#  'gleaming',
#  'black',
#  'ringmail',
#  'over',
#  'layers',
#  'of',
#  'black',
#  'wool',
#  'and',
#  'boiled',
#  'leather',
#  'ser',
#  'waymar',
#  'had',
#  'been',
#  'a',
#  'sworn',
#  'brother',
#  'of',
#  'the',
#  'night',
#  "'s",
#  'watch',
#  'for',
#  'less',
#  'than',
#  'half',
#  'a',
#  'year',
#  'but',
#  'no',
#  'one',
#  'could',
#  'say',
#  'he',
#  'had',
#  'not',
#  'prepared',
#  'for',
#  'his',
#  'vocation',
#  'at',
#  'least',
#  'insofar',
#  'as',
#  'his',
#  'wardrobe',
#  'was',
#  'concerned',
#  'his',
#  'cloak',
#  'was',
#  'his',
#  'crowning',
#  'glory',
#  'sable',
#  'thick',
#  'and',
#  'black',
#  'and',
#  'soft',
#  'as',
#  'sin',
#  'bet',
#  'he',
#  'killed',
#  'them',
#  'all',
#  'himself',
#  'he',
#  'did',
#  'gared',
#  'told',
#  'the',
#  'barracks',
#  'over',
#  'wine',
#  'twisted',
#  'their',
#  'little',
#  'heads',
#  'off',
#  'our',
#  'mighty',
#  'warrior',
#  'they',
#  'had',
#  'all',
#  'shared',
#  'the',
#  'laugh',
#  'it',
#  'is',
#  'hard',
#  'to',
#  'take',
#  'orders',
#  'from',
#  'a',
#  'man',
#  'you',
#  'laughed',
#  'at',
#  'in',
#  'your',
#  'cups',
#  'will',
#  'reflected',
#  'as',
#  'he',
#  'sat',
#  'shivering',
#  'atop',
#  'his',
#  'garron',
#  'gared',
#  'must',
#  'have',
#  'felt',
#  'the',
#  'same',
#  'mormont',
#  'said',
#  'as',
#  'we',
#  'should',
#  'track',
#  'them',
#  'and',
#  'we',
#  'did',
#  'gared',
#  'said',
#  'they',
#  "'re",
#  'dead',
#  'they',
#  'sha',
#  "n't",
#  'trouble',
#  'us',
#  'no',
#  'more',
#  'there',
#  "'s",
#  'hard',
#  'riding',
#  'before',
#  'us',
#  'i',
#  'do',
#  "n't",
#  'like',
#  'this',
#  'weather',
#  'if',
#  'it',
#  'snows',
#  'we',
#  'could',
#  'be',
#  'a',
#  'fortnight',
#  'getting',
#  'back',
#  'and',
#  'snow',
#  "'s",
#  'the',
#  'best',
#  'we',
#  'can',
#  'hope',
#  'for',
#  'ever',
#  'seen',
#  'an',
#  'ice',
#  'storm',
#  'my',
#  'lord',
#  'the',
#  'lordling',
#  'seemed',
#  'not',
#  'to',
#  'hear',
#  'him',
#  'he',
#  'studied',
#  'the',
#  'deepening',
#  'twilight',
#  'in',
#  'that',
#  'half',
#  'bored',
#  'half',
#  'distracted',
#  'way',
#  'he',
#  'had',
#  'will',
#  'had',
#  'ridden',
#  'with',
#  'the',
#  'knight',
#  'long',
#  'enough',
#  'to',
#  'understand',
#  'that',
#  'it',
#  'was',
#  'best',
#  'not',
#  'to',
#  'interrupt',
#  'him',
#  'when',
#  'he',
#  'looked',
#  'like',
#  'that',
#  'tell',
#  'me',
#  'again',
#  'what',
#  'you',
#  'saw',
#  'will',
#  'all',
#  'the',
#  'details',
#  'leave',
#  'nothing',
#  'out',
#  'will',
#  'had',
#  'been',
#  'a',
#  'hunter',
#  'before',
#  'he',
#  'joined',
#  'the',
#  'night',
#  "'s",
#  'watch',
#  'well',
#  'a',
#  'poacher',
#  'in',
#  'truth',
#  'mallister',
#  'freeriders',
#  'had',
#  'caught',
#  'him',
#  'red',
#  'handed',
#  'in',
#  'the',
#  'mallisters',
#  "'",
#  'own',
#  'woods',
#  'skinning',
#  'one',
#  'of',
#  'the',
#  'mallisters',
#  "'",
#  'own',
#  'bucks',
#  'and',
#  'it',
#  'had',
#  'been',
#  'a',
#  'choice',
#  'of',
#  'putting',
#  'on',
#  'the',
#  'black',
#  'or',
#  'losing',
#  'a',
#  'hand',
#  'no',
#  'one',
#  'could',
#  'move',
#  'through',
#  'the',
#  'woods',
#  'as',
#  'silent',
#  'as',
#  'will',
#  'and',
#  'it',
#  'had',
#  'not',
#  'taken',
#  'the',
#  'black',
#  'brothers',
#  'long',
#  'to',
#  'discover',
#  'his',
#  'talent',
#  'the',
#  'camp',
#  'is',
#  'two',
#  'miles',
#  'farther',
#  'on',
#  'over',
#  'that',
#  'ridge',
#  'hard',
#  'beside',
#  'a',
#  'stream',
#  'will',
#  'said',
#  'i',
#  'got',
#  'close',
#  'as',
#  'i',
#  'dared',
#  'there',
#  "'s",
#  'eight',
#  'of',
#  'them',
#  'men',
#  'and',
#  'women',
#  'both',
#  'no',
#  'children',
#  'i',
#  'could',
#  'see',
#  'they',
#  'put',
#  'up',
#  'a',
#  'lean',
#  'to',
#  'against',
#  'the',
#  'rock',
#  'the',
#  'snow',
#  "'s",
#  'pretty',
#  'well',
#  'covered',
#  'it',
#  'now',
#  'but',
#  'i',
#  'could',
#  'still',
#  'make',
#  'it',
#  'out',
#  'no',
#  'fire',
#  'burning',
#  'but',
#  'the',
#  'firepit',
#  'was',
#  'still',
#  'plain',
#  'as',
#  'day',
#  'no',
#  'one',
#  'moving',
#  'i',
#  'watched',
#  'a',
#  'long',
#  'time',
#  'no',
#  'living',
#  'man',
#  'ever',
#  'lay',
#  'so',
#  'still',
#  'did',
#  'you',
#  'see',
#  'any',
#  'blood',
#  'well',
#  'no',
#  'will',
#  'admitted',
#  'did',
#  'you',
#  'see',
#  'any',
#  'weapons',
#  'some',
#  'swords',
#  'a',
#  'few',
#  'bows',
#  'one',
#  'man',
#  ...]

# %%
len(tokens)
# Out:
# 7097

# %% [markdown]
# ## Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %%
text_sequences[1]
# Out:
# ['song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'a',
#  'game',
#  'of',
#  'thrones',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them',
#  'the']

# %%
' '.join(text_sequences[0])
# Out:
# 'a song of ice and fire a game of thrones prologue we should start back gared urged as the woods began to grow dark around them'

# %%
' '.join(text_sequences[1])
# Out:
# 'song of ice and fire a game of thrones prologue we should start back gared urged as the woods began to grow dark around them the'

# %%
' '.join(text_sequences[2])
# Out:
# 'of ice and fire a game of thrones prologue we should start back gared urged as the woods began to grow dark around them the wildlings'

# %%
len(text_sequences)
# Out:
# 7071

# %% [markdown]
# # Keras

# %% [markdown]
# ### Keras Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %% [markdown]
# So what we've done here is we've essentially replaced
#
# our original text sequences, which are just sequences of text 26-long
#
# to sequences that happen to have numbers in place of those words.
#
# And now the idea is that each of these numbers is an ID for a particular word.
#
# And if you ever wanna figure out the relationship you simply call tokenizer.index word.

# %%
sequences[0]
# Out:
# [4,
#  1867,
#  2,
#  213,
#  3,
#  77,
#  4,
#  1865,
#  2,
#  1864,
#  1862,
#  43,
#  465,
#  1860,
#  107,
#  25,
#  1859,
#  20,
#  1,
#  348,
#  347,
#  6,
#  1858,
#  346,
#  124,
#  49]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'his',
#  6: 'to',
#  7: 'he',
#  8: 'it',
#  9: 'was',
#  10: 'ser',
#  11: 'will',
#  12: 'in',
#  13: "'s",
#  14: 'had',
#  15: 'their',
#  16: 'lord',
#  17: 'on',
#  18: 'son',
#  19: 'king',
#  20: 'as',
#  21: 'you',
#  22: 'with',
#  23: 'that',
#  24: 'aegon',
#  25: 'gared',
#  26: 'from',
#  27: 'i',
#  28: 'royce',
#  29: 'for',
#  30: 'are',
#  31: 'not',
#  32: 'house',
#  33: 'him',
#  34: 'at',
#  35: 'waymar',
#  36: 'no',
#  37: 'they',
#  38: 'there',
#  39: 'by',
#  40: 'black',
#  41: 'cold',
#  42: 'called',
#  43: 'we',
#  44: 'is',
#  45: 'like',
#  46: 'lady',
#  47: 'when',
#  48: 'wife',
#  49: 'them',
#  50: 'prince',
#  51: 'been',
#  52: 'all',
#  53: 'said',
#  54: 'have',
#  55: 'but',
#  56: 'up',
#  57: 'did',
#  58: 'could',
#  59: 'then',
#  60: 'over',
#  61: 'its',
#  62: 'sword',
#  63: 'daughter',
#  64: 'dead',
#  65: 'an',
#  66: 'old',
#  67: 'man',
#  68: 'out',
#  69: 'years',
#  70: 'one',
#  71: 'brother',
#  72: 'snow',
#  73: 'through',
#  74: 'words',
#  75: 'eldest',
#  76: 'targaryen',
#  77: 'fire',
#  78: 'children',
#  79: 'iron',
#  80: 'during',
#  81: 'heir',
#  82: 'saw',
#  83: 'if',
#  84: 'or',
#  85: 'men',
#  86: 'see',
#  87: 'boy',
#  88: 'made',
#  89: 'wind',
#  90: 'sworn',
#  91: 'baratheon',
#  92: 'houses',
#  93: 'ii',
#  94: 'slain',
#  95: 'than',
#  96: 'long',
#  97: 'night',
#  98: 'eyes',
#  99: 'watch',
#  100: 'were',
#  101: 'young',
#  102: 'down',
#  103: 'maester',
#  104: 'other',
#  105: 'tully',
#  106: 'lords',
#  107: 'back',
#  108: 'me',
#  109: 'would',
#  110: 'never',
#  111: 'this',
#  112: 'first',
#  113: 'hard',
#  114: 'knight',
#  115: "n't",
#  116: 'lordling',
#  117: 'rock',
#  118: 'second',
#  119: 'dragon',
#  120: 'lannister',
#  121: 'master',
#  122: 'kings',
#  123: 'died',
#  124: 'around',
#  125: 'princess',
#  126: 'what',
#  127: 'be',
#  128: 'under',
#  129: 'cloak',
#  130: 'something',
#  131: 'came',
#  132: 'half',
#  133: 'red',
#  134: 'hand',
#  135: 'blood',
#  136: 'took',
#  137: 'last',
#  138: 'where',
#  139: 'great',
#  140: 'line',
#  141: 'white',
#  142: 'high',
#  143: 'girl',
#  144: 'her',
#  145: 'field',
#  146: 'queen',
#  147: 'landing',
#  148: 'principal',
#  149: '\n\n\n\n',
#  150: 'dorne',
#  151: 'captain',
#  152: 'come',
#  153: 'my',
#  154: 'light',
#  155: 'some',
#  156: 'arms',
#  157: 'away',
#  158: 'longsword',
#  159: 'moonlight',
#  160: 'blue',
#  161: 'younger',
#  162: 'greyjoy',
#  163: 'sister',
#  164: 'daeron',
#  165: 'sack',
#  166: 'do',
#  167: 'asked',
#  168: 'seen',
#  169: 'go',
#  170: 'into',
#  171: 'before',
#  172: 'turned',
#  173: 'now',
#  174: 'north',
#  175: 'again',
#  176: 'felt',
#  177: 'so',
#  178: 'your',
#  179: 'commander',
#  180: 'grey',
#  181: 'sable',
#  182: 'off',
#  183: 'looked',
#  184: 'ridge',
#  185: 'both',
#  186: 'still',
#  187: 'any',
#  188: 'winter',
#  189: 'sea',
#  190: 'three',
#  191: 'rose',
#  192: 'wood',
#  193: 'behind',
#  194: 'castle',
#  195: 'tree',
#  196: 'heard',
#  197: 'hands',
#  198: 'pale',
#  199: 'robert',
#  200: 'sigil',
#  201: 'golden',
#  202: 'isles',
#  203: 'stark',
#  204: 'jon',
#  205: 'tutor',
#  206: 'arryn',
#  207: 'lysa',
#  208: 'riverrun',
#  209: 'harren',
#  210: 'pyke',
#  211: 'viserys',
#  212: 'seven',
#  213: 'ice',
#  214: 'just',
#  215: 'enough',
#  216: 'later',
#  217: 'voice',
#  218: 'too',
#  219: 'day',
#  220: 'more',
#  221: 'wall',
#  222: 'until',
#  223: 'trees',
#  224: 'nothing',
#  225: 'ancient',
#  226: 'little',
#  227: 'can',
#  228: 'storm',
#  229: 'seemed',
#  230: 'way',
#  231: 'own',
#  232: 'against',
#  233: 'right',
#  234: 'muttered',
#  235: 'how',
#  236: 'only',
#  237: 'left',
#  238: 'found',
#  239: 'face',
#  240: 'moon',
#  241: 'here',
#  242: 'guard',
#  243: 'sentinel',
#  244: 'free',
#  245: 'between',
#  246: 'who',
#  247: 'fingers',
#  248: 'bastard',
#  249: 'lands',
#  250: 'winterfell',
#  251: 'islands',
#  252: 'aerys',
#  253: 'household',
#  254: 'healer',
#  255: 'bannermen',
#  256: 'island',
#  257: 'twin',
#  258: 'sons',
#  259: 'd',
#  260: 'frey',
#  261: 'counselor',
#  262: 'tyrell',
#  263: 'dornish',
#  264: 'highgarden',
#  265: 'martell',
#  266: 'iii',
#  267: 'himself',
#  268: 'kingdoms',
#  269: 'smile',
#  270: 'past',
#  271: 'thing',
#  272: 'hear',
#  273: 'us',
#  274: 'eight',
#  275: 'nine',
#  276: 'sky',
#  277: 'about',
#  278: 'time',
#  279: 'mouth',
#  280: 'hood',
#  281: 'yet',
#  282: 'hundred',
#  283: 'edge',
#  284: 'farther',
#  285: 'youngest',
#  286: 'destrier',
#  287: 'ringmail',
#  288: 'say',
#  289: 'garron',
#  290: 'mormont',
#  291: 'ever',
#  292: 'well',
#  293: 'mallister',
#  294: "'",
#  295: 'silent',
#  296: 'covered',
#  297: 'make',
#  298: 'few',
#  299: 'ground',
#  300: 'fallen',
#  301: 'branches',
#  302: 'far',
#  303: "m'lord",
#  304: 'whispered',
#  305: 'moved',
#  306: 'feet',
#  307: 'feel',
#  308: 'end',
#  309: 'pulled',
#  310: 'look',
#  311: 'ears',
#  312: 'aemon',
#  313: 'wrong',
#  314: 'perhaps',
#  315: 'moment',
#  316: 'sound',
#  317: 'stopped',
#  318: 'gone',
#  319: 'stood',
#  320: 'battle',
#  321: 'among',
#  322: 'eye',
#  323: 'metal',
#  324: 'met',
#  325: 'fell',
#  326: 'dragonstone',
#  327: 'city',
#  328: 'jaime',
#  329: 'descent',
#  330: 'ruled',
#  331: 'eddard',
#  332: 'warden',
#  333: 'steward',
#  334: 'casterly',
#  335: 'childbed',
#  336: 'squire',
#  337: 'knights',
#  338: 'vale',
#  339: 'waynwood',
#  340: 'trident',
#  341: 'perished',
#  342: 'oldtown',
#  343: 'redwyne',
#  344: 'sisters',
#  345: 'jaehaerys',
#  346: 'dark',
#  347: 'began',
#  348: 'woods',
#  349: 'proof',
#  350: 'rather',
#  351: 'put',
#  352: 'things',
#  353: 'forest',
#  354: 'anger',
#  355: 'thick',
#  356: 'close',
#  357: 'fear',
#  358: 'water',
#  359: 'laughed',
#  360: 'darkness',
#  361: 'each',
#  362: 'rustle',
#  363: 'leather',
#  364: 'moleskin',
#  365: 'killed',
#  366: 'shivering',
#  367: 'best',
#  368: 'hunter',
#  369: 'move',
#  370: 'brothers',
#  371: 'two',
#  372: 'beside',
#  373: 'stream',
#  374: 'got',
#  375: 'dared',
#  376: 'moving',
#  377: 'watched',
#  378: 'swords',
#  379: 'axe',
#  380: 'shivered',
#  381: 'leaves',
#  382: 'these',
#  383: 'foot',
#  384: 'deep',
#  385: 'while',
#  386: 'after',
#  387: 'pain',
#  388: 'week',
#  389: 'surely',
#  390: 'lead',
#  391: 'given',
#  392: 'honor',
#  393: 'went',
#  394: 'lying',
#  395: 'brought',
#  396: 'horse',
#  397: 'beneath',
#  398: 'gave',
#  399: 'answer',
#  400: 'slid',
#  401: 'low',
#  402: 'horses',
#  403: 'ran',
#  404: 'steel',
#  405: 'keep',
#  406: 'breath',
#  407: 'thin',
#  408: 'empty',
#  409: 'clearing',
#  410: 'below',
#  411: 'green',
#  412: 'sticky',
#  413: 'lost',
#  414: 'rush',
#  415: 'shadow',
#  416: 'silence',
#  417: 'blades',
#  418: 'bear',
#  419: 'wars',
#  420: 'conquest',
#  421: 'orys',
#  422: 'banner',
#  423: 'cersei',
#  424: 'throne',
#  425: 'selmy',
#  426: 'clegane',
#  427: 'oakheart',
#  428: 'brandon',
#  429: 'fealty',
#  430: 'fourteen',
#  431: 'age',
#  432: 'siblings',
#  433: 'elder',
#  434: 'western',
#  435: 'claim',
#  436: 'upon',
#  437: 'cousin',
#  438: 'swyft',
#  439: 'widow',
#  440: 'marbrand',
#  441: 'marriage',
#  442: 'eyrie',
#  443: 'defender',
#  444: 'suitor',
#  445: 'thousand',
#  446: 'conquered',
#  447: 'river',
#  448: 'those',
#  449: 'harrenhal',
#  450: 'whent',
#  451: 'include',
#  452: 'reach',
#  453: 'flowers',
#  454: 'hightower',
#  455: 'fossoway',
#  456: 'themselves',
#  457: 'salt',
#  458: 'wedding',
#  459: 'sunspear',
#  460: 'rhaegar',
#  461: 'rhaenys',
#  462: 'fourth',
#  463: 'third',
#  464: 'name',
#  465: 'should',
#  466: 'maid',
#  467: 'rise',
#  468: 'says',
#  469: 'known',
#  470: 'sooner',
#  471: 'mother',
#  472: 'told',
#  473: 'wet',
#  474: 'nurse',
#  475: 'same',
#  476: 'anything',
#  477: 'woman',
#  478: 'echoed',
#  479: 'ride',
#  480: 'pointed',
#  481: 'days',
#  482: 'glanced',
#  483: 'does',
#  484: 'every',
#  485: 'forty',
#  486: 'older',
#  487: 'taste',
#  488: 'shared',
#  489: 'four',
#  490: 'beyond',
#  491: 'terrors',
#  492: 'tonight',
#  493: 'riding',
#  494: 'track',
#  495: 'raiders',
#  496: 'living',
#  497: 'though',
#  498: 'loved',
#  499: 'wanted',
#  500: 'much',
#  501: 'many',
#  502: 'handsome',
#  503: 'knife',
#  504: 'huge',
#  505: 'wore',
#  506: 'fine',
#  507: 'year',
#  508: 'soft',
#  509: 'wine',
#  510: 'twisted',
#  511: 'heads',
#  512: 'mighty',
#  513: 'warrior',
#  514: 'take',
#  515: 'must',
#  516: 'snows',
#  517: 'hope',
#  518: 'twilight',
#  519: 'tell',
#  520: 'joined',
#  521: 'mallisters',
#  522: 'taken',
#  523: 'camp',
#  524: 'lean',
#  525: 'burning',
#  526: 'firepit',
#  527: 'lay',
#  528: 'double',
#  529: 'bladed',
#  530: 'cruel',
#  531: 'bodies',
#  532: 'shrugged',
#  533: 'ironwood',
#  534: 'care',
#  535: 'she',
#  536: 'chill',
#  537: 'freeze',
#  538: 'comes',
#  539: 'teeth',
#  540: 'burns',
#  541: 'starts',
#  542: 'everything',
#  543: 'warm',
#  544: 'milk',
#  545: "'ve",
#  546: 'giving',
#  547: 'frozen',
#  548: 'dress',
#  549: 'cut',
#  550: "'ll",
#  551: 'watches',
#  552: 'dozen',
#  553: 'bloody',
#  554: 'find',
#  555: 'weeping',
#  556: 'quick',
#  557: 'flurry',
#  558: 'making',
#  559: 'front',
#  560: 'roots',
#  561: 'hidden',
#  562: 'crust',
#  563: 'waiting',
#  564: 'ranging',
#  565: 'color',
#  566: 'stars',
#  567: 'better',
#  568: 'wolf',
#  569: 'dismounted',
#  570: 'why',
#  571: 'stirred',
#  572: 'alive',
#  573: 'afraid',
#  574: 'sheath',
#  575: 'splendid',
#  576: 'weapon',
#  577: 'new',
#  578: 'warned',
#  579: 'need',
#  580: 'fool',
#  581: 'enemies',
#  582: 'use',
#  583: 'finally',
#  584: 'climbed',
#  585: 'flat',
#  586: 'breathe',
#  587: 'gods',
#  588: 'slashed',
#  589: 'abandoned',
#  590: 'swept',
#  591: 'open',
#  592: 'sap',
#  593: 'needles',
#  594: 'climbing',
#  595: 'suddenly',
#  596: 'icy',
#  597: 'head',
#  598: 'another',
#  599: 'call',
#  600: 'throat',
#  601: 'cheek',
#  602: 'emerged',
#  603: 'tall',
#  604: 'armor',
#  605: 'patterns',
#  606: 'step',
#  607: 'forward',
#  608: 'human',
#  609: 'blade',
#  610: 'shard',
#  611: 'almost',
#  612: 'dance',
#  613: 'weight',
#  614: 'burned',
#  615: 'along',
#  616: 'duty',
#  617: 'watchers',
#  618: 'frost',
#  619: 'parry',
#  620: 'late',
#  621: 'arm',
#  622: 'welled',
#  623: 'touched',
#  624: 'brushed',
#  625: 'know',
#  626: 'fury',
#  627: 'closed',
#  628: 'knelt',
#  629: 'broken',
#  630: 'pupil',
#  631: 'argilac',
#  632: 'rewarded',
#  633: 'joffrey',
#  634: 'stannis',
#  635: 'florent',
#  636: 'renly',
#  637: 'baelish',
#  638: 'ships',
#  639: 'barristan',
#  640: 'kingsguard',
#  641: 'retainers',
#  642: 'payne',
#  643: 'shield',
#  644: 'summer',
#  645: 'lancel',
#  646: 'tyrek',
#  647: 'santagar',
#  648: 'kingslayer',
#  649: 'trant',
#  650: 'emmon',
#  651: 'thousands',
#  652: 'chose',
#  653: 'swear',
#  654: 'catelyn',
#  655: 'sansa',
#  656: 'ward',
#  657: 'theon',
#  658: 'mountains',
#  659: 'jeyne',
#  660: 'jory',
#  661: 'cassel',
#  662: 'desmond',
#  663: 'wyl',
#  664: 'rodrik',
#  665: 'uncle',
#  666: 'daughters',
#  667: 'septon',
#  668: 'grandson',
#  669: 'tallhart',
#  670: 'karstark',
#  671: 'bolton',
#  672: 'umber',
#  673: 'glover',
#  674: 'manderly',
#  675: 'andal',
#  676: 'female',
#  677: 'heroes',
#  678: 'gold',
#  679: 'has',
#  680: 'joanna',
#  681: 'kevan',
#  682: 'ten',
#  683: 'lefford',
#  684: 'mountain',
#  685: 'prester',
#  686: 'sellsword',
#  687: 'descended',
#  688: 'egen',
#  689: 'brynden',
#  690: 'blackfish',
#  691: 'stone',
#  692: 'service',
#  693: 'corbray',
#  694: 'redfort',
#  695: 'riverlands',
#  696: 'whose',
#  697: 'ancestors',
#  698: 'neck',
#  699: 'edmyn',
#  700: 'dominion',
#  701: 'silver',
#  702: 'ryger',
#  703: 'bracken',
#  704: 'blackwood',
#  705: 'darry',
#  706: 'vance',
#  707: 'piper',
#  708: 'lesser',
#  709: 'marches',
#  710: 'blackwater',
#  711: 'garth',
#  712: 'crown',
#  713: 'land',
#  714: 'granted',
#  715: 'strong',
#  716: 'mina',
#  717: 'paxter',
#  718: 'crane',
#  719: 'arbor',
#  720: 'horas',
#  721: 'mocked',
#  722: 'hobber',
#  723: 'tarly',
#  724: 'horn',
#  725: 'hill',
#  726: 'rowan',
#  727: 'port',
#  728: 'greyjoys',
#  729: 'urron',
#  730: 'rule',
#  731: 'qhored',
#  732: 'surviving',
#  733: 'custom',
#  734: 'harlaw',
#  735: 'rebellion',
#  736: 'realm',
#  737: 'myriah',
#  738: 'elia',
#  739: 'babe',
#  740: 'dayne',
#  741: 'targaryens',
#  742: 'valyria',
#  743: 'followed',
#  744: '37',
#  745: '42',
#  746: 'aenys',
#  747: '48',
#  748: 'maegor',
#  749: '103',
#  750: '129',
#  751: '131',
#  752: 'rhaenyra',
#  753: 'dragons',
#  754: '157',
#  755: '161',
#  756: '171',
#  757: '172',
#  758: '184',
#  759: 'naerys',
#  760: '209',
#  761: '221',
#  762: '233',
#  763: 'maekar',
#  764: '259',
#  765: 'unlikely',
#  766: '262',
#  767: 'wildlings',
#  768: 'frighten',
#  769: 'hint',
#  770: 'bait',
#  771: 'fifty',
#  772: 'lordlings',
#  773: 'business',
#  774: 'softly',
#  775: 'drag',
#  776: 'quarrel',
#  777: 'wished',
#  778: 'sing',
#  779: 'songs',
#  780: 'replied',
#  781: 'believe',
#  782: 'tit',
#  783: 'learned',
#  784: 'even',
#  785: 'loud',
#  786: 'twilit',
#  787: 'maybe',
#  788: 'falling',
#  789: 'disinterest',
#  790: 'unmanned',
#  791: 'tightness',
#  792: 'barely',
#  793: 'suppressed',
#  794: 'spent',
#  795: 'accustomed',
#  796: 'being',
#  797: 'wounded',
#  798: 'pride',
#  799: 'sense',
#  800: 'else',
#  801: 'nervous',
#  802: 'tension',
#  803: 'perilous',
#  804: 'unease',
#  805: 'sent',
#  806: 'stories',
#  807: 'rushing',
#  808: 'bowels',
#  809: 'afterward',
#  810: 'veteran',
#  811: 'rangings',
#  812: 'endless',
#  813: 'wilderness',
#  814: 'southron',
#  815: 'haunted',
#  816: 'different',
#  817: 'hackles',
#  818: 'northwest',
#  819: 'band',
#  820: 'wildling',
#  821: 'worse',
#  822: 'today',
#  823: 'worst',
#  824: 'blowing',
#  825: 'watching',
#  826: 'implacable',
#  827: 'hellbent',
#  828: 'safety',
#  829: 'feeling',
#  830: 'share',
#  831: 'especially',
#  832: 'heirs',
#  833: 'youth',
#  834: 'eighteen',
#  835: 'eyed',
#  836: 'graceful',
#  837: 'slender',
#  838: 'mounted',
#  839: 'towered',
#  840: 'above',
#  841: 'smaller',
#  842: 'garrons',
#  843: 'boots',
#  844: 'woolen',
#  845: 'pants',
#  846: 'gloves',
#  847: 'supple',
#  848: 'coat',
#  849: 'gleaming',
#  850: 'layers',
#  851: 'wool',
#  852: 'boiled',
#  853: 'less',
#  854: 'prepared',
#  855: 'vocation',
#  856: 'least',
#  857: 'insofar',
#  858: 'wardrobe',
#  859: 'concerned',
#  860: 'crowning',
#  861: 'glory',
#  862: 'sin',
#  863: 'bet',
#  864: 'barracks',
#  865: 'our',
#  866: 'laugh',
#  867: 'orders',
#  868: 'cups',
#  869: 'reflected',
#  870: 'sat',
#  871: 'atop',
#  872: "'re",
#  873: 'sha',
#  874: 'trouble',
#  875: 'weather',
#  876: 'fortnight',
#  877: 'getting',
#  878: 'studied',
#  879: 'deepening',
#  880: 'bored',
#  881: 'distracted',
#  882: 'ridden',
#  883: 'understand',
#  884: 'interrupt',
#  885: 'details',
#  886: 'leave',
#  887: 'poacher',
#  888: 'truth',
#  889: 'freeriders',
#  890: 'caught',
#  891: 'handed',
#  892: 'skinning',
#  893: 'bucks',
#  894: 'choice',
#  895: 'putting',
#  896: 'losing',
#  897: 'discover',
#  898: 'talent',
#  899: 'miles',
#  900: 'women',
#  901: 'pretty',
#  902: 'plain',
#  903: 'admitted',
#  904: 'weapons',
#  905: 'bows',
#  906: 'heavy',
#  907: 'looking',
#  908: 'piece',
#  909: 'note',
#  910: 'position',
#  911: 'couple',
#  912: 'sitting',
#  913: 'most',
#  914: 'sleeping',
#  915: 'suggested',
#  916: 'insisted',
#  917: 'hid',
#  918: 'smiled',
#  919: 'thinly',
#  920: 'closer',
#  921: 'neither',
#  922: 'despite',
#  923: 'grizzled',
#  924: 'frostfallen',
#  925: 'restlessly',
#  926: 'think',
#  927: 'might',
#  928: 'casually',
#  929: 'adjusted',
#  930: 'drape',
#  931: 'certainty',
#  932: 'everyone',
#  933: 'talks',
#  934: 'howling',
#  935: 'real',
#  936: 'enemy',
#  937: 'steals',
#  938: 'quieter',
#  939: 'shiver',
#  940: 'chatter',
#  941: 'stamp',
#  942: 'dream',
#  943: 'mulled',
#  944: 'nice',
#  945: 'hot',
#  946: 'fires',
#  947: 'gets',
#  948: 'inside',
#  949: 'fill',
#  950: 'strength',
#  951: 'fight',
#  952: 'easier',
#  953: 'sit',
#  954: 'sleep',
#  955: 'toward',
#  956: 'weak',
#  957: 'drowsy',
#  958: 'fade',
#  959: 'sinking',
#  960: 'peaceful',
#  961: 'such',
#  962: 'eloquence',
#  963: 'observed',
#  964: 'suspected',
#  965: 'good',
#  966: 'stumps',
#  967: 'toes',
#  968: 'finger',
#  969: 'ought',
#  970: 'warmly',
#  971: 'glared',
#  972: 'scars',
#  973: 'ear',
#  974: 'holes',
#  975: 'flushed',
#  976: 'hunched',
#  977: 'sullen',
#  978: 'drawn',
#  979: 'yes',
#  980: 'draw',
#  981: 'driving',
#  982: 'frowning',
#  983: 'clear',
#  984: 'froze',
#  985: 'nodded',
#  986: 'bright',
#  987: 'lad',
#  988: 'frosts',
#  989: 'fierce',
#  990: 'kill',
#  991: 'grown',
#  992: 'clad',
#  993: 'fur',
#  994: 'let',
#  995: 'remind',
#  996: 'shelter',
#  997: 'near',
#  998: 'means',
#  999: 'cocksure',
#  1000: 'myself',
#  ...}

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 4 : a
# 1867 : song
# 2 : of
# 213 : ice
# 3 : and
# 77 : fire
# 4 : a
# 1865 : game
# 2 : of
# 1864 : thrones
# 1862 : prologue
# 43 : we
# 465 : should
# 1860 : start
# 107 : back
# 25 : gared
# 1859 : urged
# 20 : as
# 1 : the
# 348 : woods
# 347 : began
# 6 : to
# 1858 : grow
# 346 : dark
# 124 : around
# 49 : them

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('a', 4562),
#              ('song', 2),
#              ('of', 6448),
#              ('ice', 134),
#              ('and', 4659),
#              ('fire', 318),
#              ('game', 8),
#              ('thrones', 10),
#              ('prologue', 11),
#              ('we', 532),
#              ('should', 65),
#              ('start', 14),
#              ('back', 249),
#              ('gared', 822),
#              ('urged', 17),
#              ('as', 980),
#              ('the', 13122),
#              ('woods', 98),
#              ('began', 99),
#              ('to', 3636),
#              ('grow', 23),
#              ('dark', 102),
#              ('around', 233),
#              ('them', 442),
#              ('wildlings', 26),
#              ('are', 728),
#              ('dead', 338),
#              ('do', 156),
#              ('frighten', 26),
#              ('you', 936),
#              ('ser', 1820),
#              ('waymar', 624),
#              ('royce', 754),
#              ('asked', 156),
#              ('with', 936),
#              ('just', 130),
#              ('hint', 26),
#              ('smile', 104),
#              ('did', 364),
#              ('not', 728),
#              ('rise', 52),
#              ('bait', 26),
#              ('he', 2028),
#              ('was', 2002),
#              ('an', 338),
#              ('old', 338),
#              ('man', 338),
#              ('past', 104),
#              ('fifty', 26),
#              ('had', 1404),
#              ('seen', 156),
#              ('lordlings', 26),
#              ('come', 182),
#              ('go', 156),
#              ('is', 520),
#              ('said', 390),
#              ('have', 390),
#              ('no', 624),
#              ('business', 26),
#              ('they', 624),
#              ('softly', 26),
#              ('what', 208),
#              ('proof', 78),
#              ('will', 1716),
#              ('saw', 286),
#              ('if', 286),
#              ('says', 52),
#              ('that', 910),
#              ("'s", 1690),
#              ('enough', 130),
#              ('for', 754),
#              ('me', 234),
#              ('known', 52),
#              ('would', 234),
#              ('drag', 26),
#              ('him', 702),
#              ('into', 156),
#              ('quarrel', 26),
#              ('sooner', 52),
#              ('or', 286),
#              ('later', 130),
#              ('wished', 26),
#              ('it', 2028),
#              ('been', 416),
#              ('rather', 78),
#              ('than', 260),
#              ('my', 182),
#              ('mother', 52),
#              ('told', 52),
#              ('men', 286),
#              ('sing', 26),
#              ('songs', 26),
#              ('put', 78),
#              ('in', 1716),
#              ('wet', 52),
#              ('nurse', 52),
#              ('same', 52),
#              ('thing', 104),
#              ('replied', 26),
#              ('never', 234),
#              ('believe', 26),
#              ('anything', 52),
#              ('hear', 104),
#              ('at', 676),
#              ('woman', 52),
#              ('tit', 26),
#              ('there', 598),
#              ('things', 78),
#              ('be', 208),
#              ('learned', 26),
#              ('even', 26),
#              ('from', 806),
#              ('his', 4336),
#              ('voice', 130),
#              ('echoed', 52),
#              ('too', 130),
#              ('loud', 26),
#              ('twilit', 26),
#              ('forest', 78),
#              ('long', 260),
#              ('ride', 52),
#              ('before', 156),
#              ('us', 104),
#              ('pointed', 52),
#              ('out', 338),
#              ('eight', 104),
#              ('days', 52),
#              ('maybe', 26),
#              ('nine', 104),
#              ('night', 260),
#              ('falling', 26),
#              ('glanced', 52),
#              ('sky', 104),
#              ('disinterest', 26),
#              ('does', 52),
#              ('every', 52),
#              ('day', 130),
#              ('about', 104),
#              ('this', 234),
#              ('time', 104),
#              ('unmanned', 26),
#              ('by', 598),
#              ('could', 364),
#              ('see', 286),
#              ('tightness', 26),
#              ('mouth', 104),
#              ('barely', 26),
#              ('suppressed', 26),
#              ('anger', 78),
#              ('eyes', 260),
#              ('under', 208),
#              ('thick', 78),
#              ('black', 572),
#              ('hood', 104),
#              ('cloak', 208),
#              ('spent', 26),
#              ('forty', 52),
#              ('years', 338),
#              ('watch', 260),
#              ('boy', 286),
#              ('accustomed', 26),
#              ('being', 26),
#              ('made', 286),
#              ('light', 182),
#              ('yet', 104),
#              ('more', 130),
#              ('wounded', 26),
#              ('pride', 26),
#              ('sense', 26),
#              ('something', 208),
#              ('else', 26),
#              ('older', 52),
#              ('taste', 52),
#              ('nervous', 26),
#              ('tension', 26),
#              ('came', 208),
#              ('perilous', 26),
#              ('close', 78),
#              ('fear', 78),
#              ('shared', 52),
#              ('unease', 26),
#              ('four', 52),
#              ('on', 1066),
#              ('wall', 130),
#              ('first', 234),
#              ('sent', 26),
#              ('beyond', 52),
#              ('all', 416),
#              ('stories', 26),
#              ('rushing', 26),
#              ('bowels', 26),
#              ('turned', 156),
#              ('water', 78),
#              ('laughed', 78),
#              ('afterward', 26),
#              ('veteran', 26),
#              ('hundred', 104),
#              ('rangings', 26),
#              ('now', 156),
#              ('endless', 26),
#              ('wilderness', 26),
#              ('southron', 26),
#              ('called', 540),
#              ('haunted', 26),
#              ('terrors', 52),
#              ('until', 130),
#              ('tonight', 52),
#              ('different', 26),
#              ('edge', 104),
#              ('darkness', 78),
#              ('hackles', 26),
#              ('riding', 52),
#              ('north', 156),
#              ('northwest', 26),
#              ('then', 364),
#              ('again', 156),
#              ('farther', 104),
#              ('hard', 234),
#              ('track', 52),
#              ('band', 26),
#              ('wildling', 26),
#              ('raiders', 52),
#              ('each', 78),
#              ('worse', 26),
#              ('today', 26),
#              ('worst', 26),
#              ('cold', 546),
#              ('wind', 286),
#              ('blowing', 26),
#              ('trees', 130),
#              ('rustle', 78),
#              ('like', 520),
#              ('living', 52),
#              ('felt', 156),
#              ('though', 52),
#              ('were', 260),
#              ('watching', 26),
#              ('implacable', 26),
#              ('loved', 52),
#              ('wanted', 52),
#              ('nothing', 130),
#              ('so', 156),
#              ('much', 52),
#              ('hellbent', 26),
#              ('safety', 26),
#              ('but', 390),
#              ('feeling', 26),
#              ('share', 26),
#              ('your', 156),
#              ('commander', 156),
#              ('especially', 26),
#              ('one', 338),
#              ('youngest', 104),
#              ('son', 1014),
#              ('ancient', 130),
#              ('house', 728),
#              ('many', 52),
#              ('heirs', 26),
#              ('handsome', 52),
#              ('youth', 26),
#              ('eighteen', 26),
#              ('grey', 156),
#              ('eyed', 26),
#              ('graceful', 26),
#              ('slender', 26),
#              ('knife', 52),
#              ('mounted', 26),
#              ('huge', 52),
#              ('destrier', 104),
#              ('knight', 234),
#              ('towered', 26),
#              ('above', 26),
#              ('their', 1352),
#              ('smaller', 26),
#              ('garrons', 26),
#              ('wore', 52),
#              ('leather', 78),
#              ('boots', 26),
#              ('woolen', 26),
#              ('pants', 26),
#              ('moleskin', 78),
#              ('gloves', 26),
#              ('fine', 52),
#              ('supple', 26),
#              ('coat', 26),
#              ('gleaming', 26),
#              ('ringmail', 104),
#              ('over', 364),
#              ('layers', 26),
#              ('wool', 26),
#              ('boiled', 26),
#              ('sworn', 286),
#              ('brother', 338),
#              ('less', 26),
#              ('half', 208),
#              ('year', 52),
#              ('say', 104),
#              ('prepared', 26),
#              ('vocation', 26),
#              ('least', 26),
#              ('insofar', 26),
#              ('wardrobe', 26),
#              ('concerned', 26),
#              ('crowning', 26),
#              ('glory', 26),
#              ('sable', 156),
#              ('soft', 52),
#              ('sin', 26),
#              ('bet', 26),
#              ('killed', 78),
#              ('himself', 129),
#              ('barracks', 26),
#              ('wine', 52),
#              ('twisted', 52),
#              ('little', 130),
#              ('heads', 52),
#              ('off', 156),
#              ('our', 26),
#              ('mighty', 52),
#              ('warrior', 52),
#              ('laugh', 26),
#              ('take', 52),
#              ('orders', 26),
#              ('cups', 26),
#              ('reflected', 26),
#              ('sat', 26),
#              ('shivering', 78),
#              ('atop', 26),
#              ('garron', 104),
#              ('must', 52),
#              ('mormont', 104),
#              ("'re", 26),
#              ('sha', 26),
#              ("n't", 234),
#              ('trouble', 26),
#              ('i', 780),
#              ('weather', 26),
#              ('snows', 52),
#              ('fortnight', 26),
#              ('getting', 26),
#              ('snow', 338),
#              ('best', 78),
#              ('can', 130),
#              ('hope', 52),
#              ('ever', 104),
#              ('storm', 130),
#              ('lord', 1240),
#              ('lordling', 234),
#              ('seemed', 130),
#              ('studied', 26),
#              ('deepening', 26),
#              ('twilight', 52),
#              ('bored', 26),
#              ('distracted', 26),
#              ('way', 130),
#              ('ridden', 26),
#              ('understand', 26),
#              ('interrupt', 26),
#              ('when', 468),
#              ('looked', 156),
#              ('tell', 52),
#              ('details', 26),
#              ('leave', 26),
#              ('hunter', 78),
#              ('joined', 52),
#              ('well', 104),
#              ('poacher', 26),
#              ('truth', 26),
#              ('mallister', 104),
#              ('freeriders', 26),
#              ('caught', 26),
#              ('red', 208),
#              ('handed', 26),
#              ('mallisters', 52),
#              ("'", 104),
#              ('own', 130),
#              ('skinning', 26),
#              ('bucks', 26),
#              ('choice', 26),
#              ('putting', 26),
#              ('losing', 26),
#              ('hand', 208),
#              ('move', 78),
#              ('through', 338),
#              ('silent', 104),
#              ('taken', 52),
#              ('brothers', 78),
#              ('discover', 26),
#              ('talent', 26),
#              ('camp', 52),
#              ('two', 78),
#              ('miles', 26),
#              ('ridge', 156),
#              ('beside', 78),
#              ('stream', 78),
#              ('got', 78),
#              ('dared', 78),
#              ('women', 26),
#              ('both', 156),
#              ('children', 312),
#              ('up', 390),
#              ('lean', 52),
#              ('against', 130),
#              ('rock', 234),
#              ('pretty', 26),
#              ('covered', 104),
#              ('still', 156),
#              ('make', 104),
#              ('burning', 52),
#              ('firepit', 52),
#              ('plain', 26),
#              ('moving', 78),
#              ('watched', 78),
#              ('lay', 52),
#              ('any', 156),
#              ('blood', 208),
#              ('admitted', 26),
#              ('weapons', 26),
#              ('some', 182),
#              ('swords', 78),
#              ('few', 104),
#              ('bows', 26),
#              ('axe', 78),
#              ('heavy', 26),
#              ('looking', 26),
#              ('double', 52),
#              ('bladed', 52),
#              ('cruel', 52),
#              ('piece', 26),
#              ('iron', 312),
#              ('ground', 104),
#              ('right', 130),
#              ('note', 26),
#              ('position', 26),
#              ('bodies', 52),
#              ('shrugged', 52),
#              ('couple', 26),
#              ('sitting', 26),
#              ('most', 26),
#              ('fallen', 104),
#              ('sleeping', 26),
#              ('suggested', 26),
#              ('insisted', 26),
#              ('ironwood', 52),
#              ('hid', 26),
#              ('branches', 104),
#              ('far', 104),
#              ('smiled', 26),
#              ('thinly', 26),
#              ('took', 208),
#              ('care', 52),
#              ('she', 52),
#              ('closer', 26),
#              ('neither', 26),
#              ('despite', 26),
#              ('shivered', 78),
#              ('chill', 52),
#              ('muttered', 130),
#              ("m'lord", 104),
#              ('young', 260),
#              ('grizzled', 26),
#              ('arms', 182),
#              ('frostfallen', 26),
#              ('leaves', 78),
#              ('whispered', 104),
#              ('moved', 104),
#              ('restlessly', 26),
#              ('think', 26),
#              ('might', 26),
#              ('these', 78),
#              ('casually', 26),
#              ('adjusted', 26),
#              ('drape', 26),
#              ('certainty', 26),
#              ('freeze', 52),
#              ('last', 208),
#              ('winter', 156),
#              ('everyone', 26),
#              ('talks', 26),
#              ('foot', 78),
#              ('deep', 78),
#              ('how', 130),
#              ('comes', 52),
#              ('howling', 26),
#              ('real', 26),
#              ('enemy', 26),
#              ('steals', 26),
#              ('quieter', 26),
#              ('shiver', 26),
#              ('teeth', 52),
#              ('chatter', 26),
#              ('stamp', 26),
#              ('feet', 104),
#              ('dream', 26),
#              ('mulled', 26),
#              ('nice', 26),
#              ('hot', 26),
#              ('fires', 26),
#              ('burns', 52),
#              ('only', 130),
#              ('while', 78),
#              ('gets', 26),
#              ('inside', 26),
#              ('starts', 52),
#              ('fill', 26),
#              ('after', 78),
#              ('strength', 26),
#              ('fight', 26),
#              ('easier', 26),
#              ('sit', 26),
#              ('down', 260),
#              ('sleep', 26),
#              ('feel', 104),
#              ('pain', 78),
#              ('toward', 26),
#              ('end', 104),
#              ('weak', 26),
#              ('drowsy', 26),
#              ('everything', 52),
#              ('fade', 26),
#              ('sinking', 26),
#              ('sea', 156),
#              ('warm', 52),
#              ('milk', 52),
#              ('peaceful', 26),
#              ('such', 26),
#              ('eloquence', 26),
#              ('observed', 26),
#              ('suspected', 26),
#              ("'ve", 52),
#              ('pulled', 104),
#              ('giving', 52),
#              ('good', 26),
#              ('look', 104),
#              ('stumps', 26),
#              ('where', 208),
#              ('ears', 104),
#              ('three', 156),
#              ('toes', 26),
#              ('finger', 26),
#              ('left', 130),
#              ('found', 130),
#              ('frozen', 52),
#              ('face', 130),
#              ('ought', 26),
#              ('dress', 52),
#              ('warmly', 26),
#              ('glared', 26),
#              ('scars', 26),
#              ('ear', 26),
#              ('holes', 26),
#              ('flushed', 26),
#              ('maester', 260),
#              ('aemon', 104),
#              ('cut', 52),
#              ('away', 182),
#              ("'ll", 52),
#              ('hunched', 26),
#              ('sullen', 26),
#              ('drawn', 26),
#              ('watches', 52),
#              ('week', 78),
#              ('yes', 26),
#              ('draw', 26),
#              ('dozen', 52),
#              ('bloody', 52),
#              ('driving', 26),
#              ('find', 52),
#              ('weeping', 52),
#              ('frowning', 26),
#              ('clear', 26),
#              ('froze', 26),
#              ('nodded', 26),
#              ('bright', 26),
#              ('lad', 26),
#              ('frosts', 26),
#              ('quick', 52),
#              ('flurry', 52),
#              ('surely', 78),
#              ('fierce', 26),
#              ('kill', 26),
#              ('grown', 26),
#              ('clad', 26),
#              ('fur', 26),
#              ('let', 26),
#              ('remind', 26),
#              ('shelter', 26),
#              ('near', 26),
#              ('means', 26),
#              ('making', 52),
#              ('cocksure', 26),
#              ('lead', 78),
#              ('myself', 26),
#              ('done', 26),
#              ('order', 26),
#              ('given', 78),
#              ('honor', 78),
#              ('bound', 26),
#              ('obey', 26),
#              ('went', 78),
#              ('front', 52),
#              ('shaggy', 26),
#              ('picking', 26),
#              ('carefully', 26),
#              ('undergrowth', 26),
#              ('stones', 26),
#              ('roots', 52),
#              ('hidden', 52),
#              ('sinks', 26),
#              ('lying', 78),
#              ('its', 364),
#              ('crust', 52),
#              ('waiting', 52),
#              ('careless', 26),
#              ('unwary', 26),
#              ('next', 26),
#              ('great', 208),
#              ('snorting', 26),
#              ('impatiently', 26),
#              ('warhorse', 26),
#              ('wrong', 104),
#              ('mount', 26),
#              ('ranging', 52),
#              ('try', 26),
#              ('brought', 78),
#              ('rear', 26),
#              ('rode', 26),
#              ('deepened', 26),
#              ('cloudless', 26),
#              ('purple', 26),
#              ('color', 52),
#              ('bruise', 26),
#              ('faded', 26),
#              ('stars', 52),
#              ('moon', 130),
#              ('rose', 156),
#              ('grateful', 26),
#              ('better', 52),
#              ('pace', 26),
#              ('full', 26),
#              ('risen', 26),
#              ('horse', 78),
#              ('insolent', 26),
#              ('perhaps', 104),
#              ('deign', 26),
#              ('reply', 26),
#              ('somewhere', 26),
#              ('wood', 156),
#              ('wolf', 52),
#              ('howled', 26),
#              ('beneath', 78),
#              ('gnarled', 26),
#              ('dismounted', 52),
#              ('why', 52),
#              ('stopping', 26),
#              ('rest', 26),
#              ('paused', 26),
#              ('moment', 104),
#              ('staring', 26),
#              ('distance', 26),
#              ('reflective', 26),
#              ('stirred', 52),
#              ('behind', 156),
#              ('alive', 52),
#              ('here', 130),
#              ('gave', 78),
#              ('disdainful', 26),
#              ('ca', 26),
#              ('listen', 26),
#              ('afraid', 52),
#              ('rustling', 26),
#              ('which', 26),
#              ('sound', 104),
#              ('unmans', 26),
#              ('answer', 78),
#              ('slid', 78),
#              ('gracefully', 26),
#              ('saddle', 26),
#              ('tied', 26),
#              ('securely', 26),
#              ('low', 78),
#              ('hanging', 26),
#              ('limb', 26),
#              ('other', 260),
#              ('horses', 78),
#              ('drew', 26),
#              ('longsword', 182),
#              ('sheath', 52),
#              ('jewels', 26),
#              ('glittered', 26),
#              ('hilt', 26),
#              ('moonlight', 182),
#              ('ran', 78),
#              ('shining', 26),
#              ('steel', 78),
#              ('splendid', 52),
#              ('weapon', 52),
#              ('castle', 156),
#              ('forged', 26),
#              ('new', 52),
#              ('doubted', 26),
#              ('swung', 26),
#              ('press', 26),
#              ('warned', 52),
#              ('sword', 364),
#              ('tangle', 26),
#              ('need', 52),
#              ('instruction', 26),
#              ('ask', 26),
#              ('stay', 26),
#              ('guard', 130),
#              ('big', 26),
#              ('fool', 52),
#              ('enemies', 52),
#              ('want', 26),
#              ('keep', 78),
#              ('bears', 26),
#              ('direwolves', 26),
#              ('andand', 26),
#              ('became', 26),
#              ('line', 208),
#              ('shadowed', 26),
#              ('glitter', 26),
#              ('stared', 26),
#              ('short', 26),
#              ('ugly', 26),
#              ('grip', 26),
#              ('discolored', 26),
#              ('sweat', 26),
#              ('nicked', 26),
#              ('use', 52),
#              ('bob', 26),
#              ('life', 26),
#              ('scabbard', 26),
#              ('finally', 52),
#              ('breath', 78),
#              ('acquiescence', 26),
#              ('threaded', 26),
#              ('thicket', 26),
#              ('started', 26),
#              ('slope', 26),
#              ('vantage', 26),
#              ('point', 26),
#              ('sentinel', 130),
#              ('tree', 156),
#              ('thin', 78),
#              ('damp', 26),
#              ('muddy', 26),
#              ('slick', 26),
#              ('footing', 26),
#              ('rocks', 26),
#              ('trip', 26),
#              ('climbed', 52),
#              ('heard', 156),
#              ('metallic', 26),
#              ('slither', 26),
#              ('curses', 26),
#              ('reaching', 26),
#              ('grabbed', 26),
#              ('tugged', 26),
#              ('top', 26),
#              ('lowest', 26),
#              ('bare', 26),
#              ('underneath', 26),
#              ('flat', 52),
#              ('belly', 26),
#              ('mud', 26),
#              ('empty', 78),
#              ('clearing', 78),
#              ('below', 78),
#              ('heart', 26),
#              ('stopped', 104),
#              ('chest', 26),
#              ('breathe', 52),
#              ('shone', 26),
#              ('ashes', 26),
#              ('hours', 26),
#              ('ago', 26),
#              ('gone', 104),
#              ('gods', 52),
#              ('slashed', 52),
#              ('branch', 26),
#              ('gained', 26),
#              ('stood', 104),
#              ('billowing', 26),
#              ('outlined', 26),
#              ('nobly', 26),
#              ('get', 26),
#              ('urgently', 26),
#              ('seem', 26),
#              ('abandoned', 52),
#              ('groped', 26),
#              ('words', 338),
#              ('possible', 26),
#              ('swept', 52),
#              ('forth', 26),
#              ('campsite', 26),
#              ('battle', 104),
#              ('untouched', 26),
#              ('valuable', 26),
#              ('commanded', 26),
#              ('wo', 26),
#              ('hiding', 26),
#              ('bush', 26),
#              ('reluctantly', 26),
#              ('obeyed', 26),
#              ('open', 52),
#              ('disapproval', 26),
#              ('am', 26),
#              ('going', 26),
#              ('failure', 26),
#              ('wordless', 26),
#              ('argue', 26),
#              ('vaulting', 26),
#              ('green', 78),
#              ('climb', 26),
#              ('soon', 26),
#              ('hands', 156),
#              ('sticky', 78),
#              ('sap', 52),
#              ('lost', 78),
#              ('among', 104),
#              ('needles', 52),
#              ('filled', 26),
#              ('gut', 26),
#              ('meal', 26),
#              ('digest', 26),
#              ('prayer', 26),
#              ('nameless', 26),
#              ('slipped', 26),
#              ('dirk', 26),
#              ('free', 130),
#              ('between', 130),
#              ('climbing', 52),
#              ('comfort', 26),
#              ('suddenly', 52),
#              ('who', 130),
#              ('goes', 26),
#              ('uncertainty', 26),
#              ('challenge', 26),
#              ('listened', 26),
#              ('icy', 52),
#              ('rush', 78),
#              ('distant', 26),
#              ('hoot', 26),
#              ('owl', 26),
#              ('others', 26),
#              ('movement', 26),
#              ('corner', 26),
#              ('eye', 104),
#              ('pale', 156),
#              ('shapes', 26),
#              ('gliding', 26),
#              ('head', 52),
#              ('glimpsed', 26),
#              ('white', 208),
#              ('shadow', 78),
#              ('gently', 26),
#              ('scratching', 26),
#              ('another', 52),
#              ('wooden', 26),
#              ('fingers', 130),
#              ('opened', 26),
#              ('call', 52),
#              ('warning', 26),
#              ('throat', 52),
#              ('bird', 26),
#              ('reflection', 26),
#              ('trick', 26),
#              ('turning', 26),
#              ('slow', 26),
#              ('circle', 26),
#              ('wary', 26),
#              ('clung', 26),
#              ('tightly', 26),
#              ('perch', 26),
#              ('pressed', 26),
#              ('trunk', 26),
#              ('sweet', 26),
#              ('cheek', 52),
#              ('emerged', 52),
#              ('tall', 52),
#              ('gaunt', 26),
#              ('bones', 26),
#              ('flesh', 26),
#              ('armor', 52),
#              ('change', 26),
#              ('everywhere', 26),
#              ('dappled', 26),
#              ('patterns', 52),
#              ('step', 52),
#              ('hiss', 26),
#              ('cracked', 26),
#              ('threw', 26),
#              ('shoulders', 26),
#              ('very', 26),
#              ('forward', 52),
#              ('none', 26),
#              ('human', 52),
#              ('metal', 104),
#              ('forging', 26),
#              ('blade', 52),
#              ('translucent', 26),
#              ('shard', 52),
#              ('crystal', 26),
#              ('almost', 52),
#              ('vanish', 26),
#              ('faint', 26),
#              ('blue', 182),
#              ('shimmer', 26),
#              ('ghost', 26),
#              ('played', 26),
#              ('edges', 26),
#              ('somehow', 26),
#              ('knew', 26),
#              ('sharper', 26),
#              ('razor', 26),
#              ('met', 104),
#              ('bravely', 26),
#              ('dance', 52),
#              ('lifted', 26),
#              ('high', 208),
#              ('defiant', 26),
#              ('trembled', 26),
#              ('weight', 52),
#              ('thought', 26),
#              ('longer', 26),
#              ('halted', 26),
#              ('deeper', 26),
#              ('bluer', 26),
#              ('burned', 52),
#              ('fixed', 26),
#              ('trembling', 26),
#              ('running', 26),
#              ('along', 52),
#              ('heartbeat', 26),
#              ('silently', 26),
#              ('shadows', 26),
#              ('twins', 26),
#              ('themfourfiveser', 26),
#              ('may', 26),
#              ('duty', 52),
#              ('death', 26),
#              ('hugged', 26),
#              ('kept', 26),
#              ('silence', 78),
#              ('air', 26),
#              ('blades', 78),
#              ('ring', 26),
#              ('hearing', 26),
#              ('animal', 26),
#              ('screaming', 26),
#              ('checked', 26),
#              ('second', 234),
#              ('blow', 26),
#              ('third', 74),
#              ('fell', 104),
#              ('blows', 26),
#              ('watchers', 52),
#              ('patient', 26),
#              ('faceless', 26),
#              ('shifting', 26),
#              ('delicate', 26),
#              ('invisible', 26),
#              ('interfere', 26),
#              ('cover', 26),
#              ('strange', 26),
#              ('anguished', 26),
#              ('keening', 26),
#              ('clash', 26),
#              ('panting', 26),
#              ('effort', 26),
#              ('steaming', 26),
#              ('frost', 52),
#              ('danced', 26),
#              ('parry', 52),
#              ('beat', 26),
#              ('late', 52),
#              ('bit', 26),
#              ('arm', 52),
#              ('cried', 26),
#              ('welled', 52),
#              ('rings', 26),
#              ('steamed', 26),
#              ('droplets', 26),
#              ('touched', 52),
#              ('brushed', 52),
#              ('side', 26),
#              ('glove', 26),
#              ('soaked', 26),
#              ('language', 26),
#              ('know', 52),
#              ('cracking', 26),
#              ('lake', 26),
#              ('mocking', 26),
#              ('fury', 52),
#              ('robert', 156),
#              ('shouted', 26),
#              ('snarling', 26),
#              ('lifting', 26),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)

# %%
vocabulary_size
# Out:
# 1868

# %% [markdown]
# ### Convert to Numpy Matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[   4, 1867,    2, ...,  346,  124,   49],
#        [1867,    2,  213, ...,  124,   49,    1],
#        [   2,  213,    3, ...,   49,    1,  767],
#        ...,
#        [  50,  211, 1857, ..., 1866,    4,  466],
#        [ 211, 1857,  267, ...,    4,  466,    2],
#        [1857,  267,  211, ...,  466,    2, 1868]])

# %% [markdown]
# # Creating an LSTM based model

# %% [markdown]
# So for this lecture,
#
# we're going to show you how to create the LSTM based model
#
# but before we do that,
#
# we want to split the data into features and labels.
#
# So we're going to have our X features
#
# which is the first N words of the sequence
#
# and then we'll have our Y label
#
# which is the very next word after that entire sequence.
#
# Once we've done that,
#
# we'll be able to fit the model on that feature data
#
# in order to predict the next word in the sequence.

# %% [markdown]
# ### Train / Test Split

# %%
from keras.utils import to_categorical

# %%
sequences
# Out:
# array([[   4, 1867,    2, ...,  346,  124,   49],
#        [1867,    2,  213, ...,  124,   49,    1],
#        [   2,  213,    3, ...,   49,    1,  767],
#        ...,
#        [  50,  211, 1857, ..., 1866,    4,  466],
#        [ 211, 1857,  267, ...,    4,  466,    2],
#        [1857,  267,  211, ...,  466,    2, 1868]])

# %%
# First 49 words
sequences[:,:-1]
# Out:
# array([[   4, 1867,    2, ..., 1858,  346,  124],
#        [1867,    2,  213, ...,  346,  124,   49],
#        [   2,  213,    3, ...,  124,   49,    1],
#        ...,
#        [  50,  211, 1857, ..., 1861, 1866,    4],
#        [ 211, 1857,  267, ..., 1866,    4,  466],
#        [1857,  267,  211, ...,    4,  466,    2]])

# %%
# last Word
sequences[:,-1]
# Out:
# array([  49,    1,  767, ...,  466,    2, 1868])

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
seq_len
# Out:
# 25

# %% [markdown]
# ### Training the Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %% [markdown]
# from keras.models import sequential
#
# and then from keras.layers import
#
# and we'll be importing a dense layer
#
# and LSTM layer to deal with the sequences
#
# and an embedding layer to deal with the vocabulary

# %%
def create_model(vocabulary_size, seq_len):
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25))  # Remove input_length argument
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150, activation='relu'))
    model.add(Dense(vocabulary_size, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Build the model to calculate output shapes and parameter counts
    model.build((None, seq_len))  # Pass input shape (batch_size, seq_len)
    # Print the summary
    model.summary()
    return model

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 25, 25)              │          46,725 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 25, 150)             │         105,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 150)                 │         180,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 150)                 │          22,650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1869)                │         282,219 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 637,794 (2.43 MB)
#  Trainable params: 637,794 (2.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---
#
# ----

# %% [markdown]
# but if you saw the summary, then you are good to go.
#
# Okay, so coming up next we're going to generate new text.
#
# So the last thing to do here
#
# is actually train and fit our model.
#
# So what we do is we're going to say,
#
# from pickle import dump, load.
#
# That's going to allow us to actually save the file
#
# and then load it up later on.

# %%
from pickle import dump,load

# %%
# fit model
model.fit(X, y, batch_size=128, epochs=300,verbose=1)
# Out:
# Epoch 1/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.0715 - loss: 6.0783
# Epoch 2/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.0699 - loss: 6.0701
# Epoch 3/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.0768 - loss: 5.8589
# Epoch 4/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.0804 - loss: 5.7745
# Epoch 5/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.0816 - loss: 5.7443
# Epoch 6/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - accuracy: 0.0810 - loss: 5.6422
# Epoch 7/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.0848 - loss: 5.5415
# Epoch 8/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.0824 - loss: 5.4558
# Epoch 9/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.0908 - loss: 5.4175
# Epoch 10/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.0848 - loss: 5.3645
# Epoch 11/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.0835 - loss: 5.3086
# Epoch 12/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.0887 - loss: 5.2234
# Epoch 13/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.0873 - loss: 5.1729
# Epoch 14/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.0935 - loss: 5.1002
# Epoch 15/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.0976 - loss: 5.0178
# Epoch 16/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 186ms/step - accuracy: 0.0955 - loss: 4.9515
# Epoch 17/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.0953 - loss: 4.8976
# Epoch 18/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 111s 193ms/step - accuracy: 0.1055 - loss: 4.8113
# Epoch 19/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.1041 - loss: 4.7573
# Epoch 20/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.1066 - loss: 4.7017
# Epoch 21/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.1044 - loss: 4.6665
# Epoch 22/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.1022 - loss: 4.6026
# Epoch 23/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.1085 - loss: 4.5390
# Epoch 24/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.1115 - loss: 4.5065
# Epoch 25/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.1067 - loss: 4.4632
# Epoch 26/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.1152 - loss: 4.4212
# Epoch 27/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.1258 - loss: 4.3390
# Epoch 28/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.1203 - loss: 4.2687
# Epoch 29/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.1218 - loss: 4.2653
# Epoch 30/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.1137 - loss: 4.2406
# Epoch 31/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.1216 - loss: 4.1746
# Epoch 32/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.1271 - loss: 4.1483
# Epoch 33/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - accuracy: 0.1323 - loss: 4.0887
# Epoch 34/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 191ms/step - accuracy: 0.1266 - loss: 4.0572
# Epoch 35/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.1352 - loss: 3.9515
# Epoch 36/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 256ms/step - accuracy: 0.1463 - loss: 3.9297
# Epoch 37/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.1441 - loss: 3.8734
# Epoch 38/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.1432 - loss: 3.8727
# Epoch 39/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.1390 - loss: 3.8447
# Epoch 40/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.1580 - loss: 3.7952
# Epoch 41/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.1573 - loss: 3.7543
# Epoch 42/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.1628 - loss: 3.7351
# Epoch 43/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.1589 - loss: 3.6846
# Epoch 44/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.1658 - loss: 3.6219
# Epoch 45/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.1692 - loss: 3.6148
# Epoch 46/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step - accuracy: 0.1821 - loss: 3.5586
# Epoch 47/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.1859 - loss: 3.5318
# Epoch 48/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.1834 - loss: 3.5051
# Epoch 49/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.1818 - loss: 3.4664
# Epoch 50/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.1945 - loss: 3.4549
# Epoch 51/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - accuracy: 0.2089 - loss: 3.3900
# Epoch 52/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.2045 - loss: 3.3478
# Epoch 53/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.2146 - loss: 3.3101
# Epoch 54/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.2121 - loss: 3.2984
# Epoch 55/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.2174 - loss: 3.2542
# Epoch 56/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.2362 - loss: 3.2008
# Epoch 57/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.2351 - loss: 3.2118
# Epoch 58/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 252ms/step - accuracy: 0.2473 - loss: 3.1555
# Epoch 59/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - accuracy: 0.2428 - loss: 3.1255
# Epoch 60/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.2635 - loss: 3.0820
# Epoch 61/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 229ms/step - accuracy: 0.2662 - loss: 3.0451
# Epoch 62/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.2592 - loss: 3.0514
# Epoch 63/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.2684 - loss: 3.0048
# Epoch 64/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 241ms/step - accuracy: 0.2800 - loss: 2.9687
# Epoch 65/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 204ms/step - accuracy: 0.2806 - loss: 2.9515
# Epoch 66/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.2788 - loss: 2.9258
# Epoch 67/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.2952 - loss: 2.8563
# Epoch 68/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.2986 - loss: 2.8455
# Epoch 69/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.3057 - loss: 2.8048
# Epoch 70/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.3190 - loss: 2.7785
# Epoch 71/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.3229 - loss: 2.7652
# Epoch 72/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.3238 - loss: 2.7144
# Epoch 73/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.3355 - loss: 2.7018
# Epoch 74/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.3458 - loss: 2.6649
# Epoch 75/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.3330 - loss: 2.6778
# Epoch 76/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.3561 - loss: 2.5831
# Epoch 77/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.3652 - loss: 2.5879
# Epoch 78/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.3642 - loss: 2.5634
# Epoch 79/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.3752 - loss: 2.5236
# Epoch 80/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.3720 - loss: 2.5022
# Epoch 81/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.3833 - loss: 2.4581
# Epoch 82/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.3828 - loss: 2.4386
# Epoch 83/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.3841 - loss: 2.4219
# Epoch 84/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.4015 - loss: 2.3870
# Epoch 85/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.4159 - loss: 2.3326
# Epoch 86/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.4141 - loss: 2.3277
# Epoch 87/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.4013 - loss: 2.3308
# Epoch 88/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 206ms/step - accuracy: 0.4239 - loss: 2.3035
# Epoch 89/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.4218 - loss: 2.2742
# Epoch 90/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.4307 - loss: 2.2374
# Epoch 91/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.4370 - loss: 2.2178
# Epoch 92/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 226ms/step - accuracy: 0.4378 - loss: 2.2073
# Epoch 93/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4400 - loss: 2.1950
# Epoch 94/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.4575 - loss: 2.1453
# Epoch 95/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.4519 - loss: 2.1172
# Epoch 96/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.4624 - loss: 2.0966
# Epoch 97/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.4737 - loss: 2.0762
# Epoch 98/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 192ms/step - accuracy: 0.4669 - loss: 2.0754
# Epoch 99/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 213ms/step - accuracy: 0.4870 - loss: 2.0388
# Epoch 100/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - accuracy: 0.4662 - loss: 2.0328
# Epoch 101/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.4811 - loss: 2.0116
# Epoch 102/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.4881 - loss: 1.9709
# Epoch 103/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.4951 - loss: 1.9673
# Epoch 104/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - accuracy: 0.4908 - loss: 1.9506
# Epoch 105/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - accuracy: 0.5039 - loss: 1.9214
# Epoch 106/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.5127 - loss: 1.9054
# Epoch 107/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.5105 - loss: 1.8892
# Epoch 108/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 204ms/step - accuracy: 0.5123 - loss: 1.8932
# Epoch 109/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.5042 - loss: 1.8982
# Epoch 110/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5282 - loss: 1.8253
# Epoch 111/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.5256 - loss: 1.8214
# Epoch 112/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.5363 - loss: 1.7861
# Epoch 113/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.5362 - loss: 1.7852
# Epoch 114/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 205ms/step - accuracy: 0.5359 - loss: 1.7857
# Epoch 115/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 253ms/step - accuracy: 0.5369 - loss: 1.7686
# Epoch 116/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.5468 - loss: 1.7320
# Epoch 117/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 207ms/step - accuracy: 0.5417 - loss: 1.7375
# Epoch 118/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 206ms/step - accuracy: 0.5493 - loss: 1.7206
# Epoch 119/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.5543 - loss: 1.7066
# Epoch 120/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.5602 - loss: 1.6864
# Epoch 121/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.5585 - loss: 1.6789
# Epoch 122/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 209ms/step - accuracy: 0.5671 - loss: 1.6607
# Epoch 123/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.5732 - loss: 1.6148
# Epoch 124/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.5855 - loss: 1.5844
# Epoch 125/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.5859 - loss: 1.5992
# Epoch 126/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.5777 - loss: 1.6099
# Epoch 127/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 210ms/step - accuracy: 0.5946 - loss: 1.5567
# Epoch 128/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 227ms/step - accuracy: 0.5834 - loss: 1.5747
# Epoch 129/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.5879 - loss: 1.5672
# Epoch 130/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 204ms/step - accuracy: 0.6033 - loss: 1.5234
# Epoch 131/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - accuracy: 0.6058 - loss: 1.4983
# Epoch 132/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.5981 - loss: 1.5112
# Epoch 133/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6272 - loss: 1.4546
# Epoch 134/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - accuracy: 0.6098 - loss: 1.4774
# Epoch 135/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.6109 - loss: 1.4616
# Epoch 136/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.6106 - loss: 1.4841
# Epoch 137/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.6204 - loss: 1.4451
# Epoch 138/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 205ms/step - accuracy: 0.6141 - loss: 1.4821
# Epoch 139/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.6068 - loss: 1.4579
# Epoch 140/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - accuracy: 0.6234 - loss: 1.4085
# Epoch 141/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.6386 - loss: 1.3794
# Epoch 142/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 203ms/step - accuracy: 0.6365 - loss: 1.3778
# Epoch 143/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6431 - loss: 1.3530
# Epoch 144/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 204ms/step - accuracy: 0.6292 - loss: 1.3719
# Epoch 145/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.6498 - loss: 1.3297
# Epoch 146/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - accuracy: 0.6458 - loss: 1.3328
# Epoch 147/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.6538 - loss: 1.3196
# Epoch 148/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.6518 - loss: 1.3140
# Epoch 149/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6552 - loss: 1.3089
# Epoch 150/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.6626 - loss: 1.2882
# Epoch 151/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.6623 - loss: 1.2718
# Epoch 152/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6701 - loss: 1.2589
# Epoch 153/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 238ms/step - accuracy: 0.6617 - loss: 1.2688
# Epoch 154/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.6702 - loss: 1.2277
# Epoch 155/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6799 - loss: 1.2181
# Epoch 156/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.6739 - loss: 1.2369
# Epoch 157/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6779 - loss: 1.2146
# Epoch 158/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 204ms/step - accuracy: 0.6924 - loss: 1.1798
# Epoch 159/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6796 - loss: 1.2027
# Epoch 160/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6887 - loss: 1.1755
# Epoch 161/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.6880 - loss: 1.1762
# Epoch 162/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.6955 - loss: 1.1609
# Epoch 163/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.7012 - loss: 1.1286
# Epoch 164/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.6949 - loss: 1.1495
# Epoch 165/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 203ms/step - accuracy: 0.6994 - loss: 1.1306
# Epoch 166/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 204ms/step - accuracy: 0.7104 - loss: 1.1061
# Epoch 167/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - accuracy: 0.7082 - loss: 1.0901
# Epoch 168/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.7075 - loss: 1.1043
# Epoch 169/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.7125 - loss: 1.0906
# Epoch 170/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.7150 - loss: 1.0773
# Epoch 171/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.7120 - loss: 1.0812
# Epoch 172/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.7150 - loss: 1.0655
# Epoch 173/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.7263 - loss: 1.0363
# Epoch 174/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 205ms/step - accuracy: 0.7300 - loss: 1.0082
# Epoch 175/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 203ms/step - accuracy: 0.7240 - loss: 1.0259
# Epoch 176/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 211ms/step - accuracy: 0.7224 - loss: 1.0248
# Epoch 177/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.7323 - loss: 1.0195
# Epoch 178/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 221ms/step - accuracy: 0.7341 - loss: 1.0028
# Epoch 179/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.7348 - loss: 0.9963
# Epoch 180/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.7497 - loss: 0.9553
# Epoch 181/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 226ms/step - accuracy: 0.7333 - loss: 0.9868
# Epoch 182/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.7516 - loss: 0.9343
# Epoch 183/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.7424 - loss: 0.9758
# Epoch 184/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 190ms/step - accuracy: 0.7429 - loss: 0.9544
# Epoch 185/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.7457 - loss: 0.9527
# Epoch 186/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.7562 - loss: 0.9284
# Epoch 187/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.7496 - loss: 0.9320
# Epoch 188/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 0.7685 - loss: 0.8812
# Epoch 189/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.7605 - loss: 0.9067
# Epoch 190/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.7765 - loss: 0.8619
# Epoch 191/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.7660 - loss: 0.8818
# Epoch 192/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.7647 - loss: 0.8790
# Epoch 193/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - accuracy: 0.7728 - loss: 0.8639
# Epoch 194/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 220ms/step - accuracy: 0.7784 - loss: 0.8426
# Epoch 195/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.7852 - loss: 0.8545
# Epoch 196/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 227ms/step - accuracy: 0.7817 - loss: 0.8162
# Epoch 197/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 230ms/step - accuracy: 0.7798 - loss: 0.8412
# Epoch 198/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 223ms/step - accuracy: 0.7811 - loss: 0.8273
# Epoch 199/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.7804 - loss: 0.8404
# Epoch 200/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.7928 - loss: 0.7915
# Epoch 201/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - accuracy: 0.7880 - loss: 0.7996
# Epoch 202/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.7893 - loss: 0.7885
# Epoch 203/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 223ms/step - accuracy: 0.7867 - loss: 0.7992
# Epoch 204/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 261ms/step - accuracy: 0.7850 - loss: 0.7985
# Epoch 205/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 239ms/step - accuracy: 0.7916 - loss: 0.7736
# Epoch 206/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - accuracy: 0.8050 - loss: 0.7539
# Epoch 207/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 140ms/step - accuracy: 0.8096 - loss: 0.7393
# Epoch 208/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - accuracy: 0.8113 - loss: 0.7308
# Epoch 209/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.8171 - loss: 0.7105
# Epoch 210/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.8185 - loss: 0.7105
# Epoch 211/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8419 - loss: 0.6334
# Epoch 223/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - accuracy: 0.8457 - loss: 0.6205
# Epoch 224/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.8508 - loss: 0.6064
# Epoch 225/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.8631 - loss: 0.5815
# Epoch 226/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - accuracy: 0.8688 - loss: 0.5678
# Epoch 227/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 152ms/step - accuracy: 0.8690 - loss: 0.5511
# Epoch 228/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.8701 - loss: 0.5455
# Epoch 229/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - accuracy: 0.8743 - loss: 0.5390
# Epoch 230/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 147ms/step - accuracy: 0.8747 - loss: 0.5261
# Epoch 231/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.8711 - loss: 0.5320
# Epoch 232/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.8820 - loss: 0.4991
# Epoch 233/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9178 - loss: 0.3830
# Epoch 256/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9172 - loss: 0.3918
# Epoch 257/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9231 - loss: 0.3660
# Epoch 258/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9249 - loss: 0.3528
# Epoch 259/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9340 - loss: 0.3375
# Epoch 260/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9410 - loss: 0.3205
# Epoch 261/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9427 - loss: 0.3155
# Epoch 262/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9446 - loss: 0.2953
# Epoch 263/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9486 - loss: 0.2965
# Epoch 264/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9523 - loss: 0.2893
# Epoch 265/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9420 - loss: 0.2919
# Epoch 266/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9537 - loss: 0.2793
# Epoch 267/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.9502 - loss: 0.2825
# Epoch 268/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - accuracy: 0.9499 - loss: 0.2796
# Epoch 269/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9444 - loss: 0.2908
# Epoch 270/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9447 - loss: 0.2856
# Epoch 271/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.9337 - loss: 0.3290
# Epoch 272/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9450 - loss: 0.3018
# Epoch 273/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 246ms/step - accuracy: 0.9441 - loss: 0.2949
# Epoch 274/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 264ms/step - accuracy: 0.9240 - loss: 0.3442
# Epoch 275/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8317 - loss: 0.6136
# Epoch 276/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.8740 - loss: 0.4732
# Epoch 277/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.9134 - loss: 0.3773
# Epoch 278/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9474 - loss: 0.2983
# Epoch 279/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 222ms/step - accuracy: 0.9637 - loss: 0.2339
# Epoch 280/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 239ms/step - accuracy: 0.9700 - loss: 0.2075
# Epoch 281/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9730 - loss: 0.1936
# Epoch 282/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9755 - loss: 0.1887
# Epoch 283/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.9784 - loss: 0.1809
# Epoch 284/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 222ms/step - accuracy: 0.9781 - loss: 0.1765
# Epoch 285/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.9805 - loss: 0.1763
# Epoch 286/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.9786 - loss: 0.1726
# Epoch 287/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9814 - loss: 0.1634
# Epoch 288/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 222ms/step - accuracy: 0.9851 - loss: 0.1596
# Epoch 289/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9838 - loss: 0.1561
# Epoch 290/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9824 - loss: 0.1605
# Epoch 291/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.9835 - loss: 0.1513
# Epoch 292/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.9836 - loss: 0.1605
# Epoch 293/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 156ms/step - accuracy: 0.9872 - loss: 0.1452
# Epoch 294/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 205ms/step - accuracy: 0.9851 - loss: 0.1432
# Epoch 295/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 240ms/step - accuracy: 0.9855 - loss: 0.1407
# Epoch 296/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.9895 - loss: 0.1326
# Epoch 297/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - accuracy: 0.9894 - loss: 0.1335
# Epoch 298/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 247ms/step - accuracy: 0.9929 - loss: 0.1226
# Epoch 299/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.9887 - loss: 0.1259
# Epoch 300/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.9910 - loss: 0.1172

# %%
# save the model to file
model.save('game_of_thrones.txt.keras')
# save the tokenizer
dump(tokenizer, open('game_of_thrones.txt', 'wb'))

# %% [markdown]
# # Generating New Text

# %%
from random import randint
from pickle import load

# %%
from keras.models import load_model

# %%
#from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''
    
    # Final Output
    output_text = []
    
    # Initial Seed Sequence
    input_text = seed_text
    
    # Create num_gen_words
    for i in range(num_gen_words):
        
        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        
        # Pad sequences to our trained rate 
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')
        
        # Predict Class Probabilities for each word
        pred_probabilities = model.predict(pad_encoded, verbose=0)[0]
        
        # Sample the index of the next word based on predicted probabilities
        next_word_index = np.random.choice(len(pred_probabilities), p=pred_probabilities)
        
        # Convert index to word
        pred_word = tokenizer.index_word[next_word_index + 1]  # Adjust index by 1
        
        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word
        
        output_text.append(pred_word)
        
    # Make it look like a sentence.
    return ' '.join(output_text)

# %% [markdown]
# ### Grab a random seed sequence

# %%
text_sequences[0]
# Out:
# ['a',
#  'song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'a',
#  'game',
#  'of',
#  'thrones',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them']

# %%
import random

# %%
random.seed(101)
random_pick_1 = random.randint(0,len(text_sequences))

# %%
random.seed(102)
random_pick_2 = random.randint(0, len(text_sequences))

# %%
random.seed(103)
random_pick_3 = random.randint(0, len(text_sequences))

# %%
random_seed_text_1 = text_sequences[random_pick_1]

# %%
random_seed_text_2 = text_sequences[random_pick_2]

# %%
random_seed_text_3 = text_sequences[random_pick_3]

# %%
random_seed_text_1
# Out:
# ['their',
#  'son',
#  'tyrek',
#  'squire',
#  'to',
#  'the',
#  'king',
#  'gerion',
#  'his',
#  'youngest',
#  'brother',
#  'lost',
#  'at',
#  'sea',
#  'his',
#  'bastard',
#  'daughter',
#  'joy',
#  'a',
#  'girl',
#  'of',
#  'ten',
#  'their',
#  'cousin',
#  'ser',
#  'stafford']

# %%
random_seed_text_2
# Out:
# ['will',
#  'and',
#  'at',
#  'first',
#  'you',
#  'shiver',
#  'and',
#  'your',
#  'teeth',
#  'chatter',
#  'and',
#  'you',
#  'stamp',
#  'your',
#  'feet',
#  'and',
#  'dream',
#  'of',
#  'mulled',
#  'wine',
#  'and',
#  'nice',
#  'hot',
#  'fires',
#  'it',
#  'burns']

# %%
random_seed_text_3
# Out:
# ['islands',
#  'called',
#  'ironmen',
#  'by',
#  'those',
#  'they',
#  'plundered',
#  'were',
#  'the',
#  'terrors',
#  'of',
#  'the',
#  'seas',
#  'sailing',
#  'as',
#  'far',
#  'as',
#  'the',
#  'port',
#  'of',
#  'ibben',
#  'and',
#  'the',
#  'summer',
#  'isles',
#  'they']

# %%
seed_text_1 = ' '.join(random_seed_text_1)

# %%
seed_text_2 = ' '.join(random_seed_text_2)

# %%
seed_text_3 = ' '.join(random_seed_text_3)

# %%
seed_text_1
# Out:
# 'their son tyrek squire to the king gerion his youngest brother lost at sea his bastard daughter joy a girl of ten their cousin ser stafford'

# %%
seed_text_2
# Out:
# 'will and at first you shiver and your teeth chatter and you stamp your feet and dream of mulled wine and nice hot fires it burns'

# %%
seed_text_3
# Out:
# 'islands called ironmen by those they plundered were the terrors of the seas sailing as far as the port of ibben and the summer isles they'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text_1,num_gen_words=25)
# Out:
# 'master snow age he of of of had rewarded had longer of siblings of of of of came had royce houses king it double tightness'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text_2,num_gen_words=25)
# Out:
# 'was every observed a wine fell son lord of of of sigil left royce ser king a no white half dance of of of of'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text_3,num_gen_words=25)
# Out:
# 'fierceness to gods ended and fade a dead to is to interrupt like and in of of at of son and escaped of of at'
